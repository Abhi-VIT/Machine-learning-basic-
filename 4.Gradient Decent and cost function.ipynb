# %% [markdown]
# ## **Gradient Decent and cost function**

# %% [markdown]
# ![image.png](attachment:2a405943-d816-43a1-8938-190e25ce8af3.png)

# %% [markdown]
# **Gradient descent is an algorithm that finds best fit line for given training data set**

# %% [markdown]
# ![image.png](attachment:1416f212-d8ab-4912-b069-c1c54bbf314b.png)

# %% [markdown]
# ## **MSE (cost)**

# %% [markdown]
# ![image.png](attachment:2facdf98-35ac-4089-b0f6-dece3b7084ef.png)

# %% [markdown]
#  ### **Differentiation in python**

# %%
import sympy as sp
x = sp.symbols('x')
y = sp.symbols('y')
equation = x**3 + x**2 +2
derivation = sp.diff(equation, x)
derivation
# Out:
# 3*x**2 + 2*x

# %% [markdown]
#  ### **Integration in python**

# %%
import sympy as sp
x = sp.symbols('x')
equation = x**3 + x**2 +2
integration = sp.integrate(equation, x)
integration
# Out:
# x**4/4 + x**3/3 + 2*x

# %% [markdown]
# # **threeblue one brown (youtube channel)**

# %% [markdown]
# ![image.png](attachment:7081b47e-e318-41fc-a3db-82532610b7ae.png)

# %% [markdown]
# ![image.png](attachment:5c44c3f9-ddd6-4574-bad1-8af310abad41.png)

# %% [markdown]
# # **formula**

# %% [markdown]
# ![image.png](attachment:feba294b-c649-4fb7-b813-440a6738dcc0.png)

# %% [markdown]
# # **Learning rate**

# %% [markdown]
# ![image.png](attachment:b6cd4778-19e8-436e-8a5b-963773d6fa30.png)

# %% [markdown]
# # **graphical representation**

# %% [markdown]
# ![image.png](attachment:7dd7e13e-1069-4e9f-8e95-cdcbdd10f1e5.png)

# %% [markdown]
# # **Gradient Descent implemantation**

# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:4b7ce345-45ca-4d79-a6b3-b9e33f58781d.png)

# %% [markdown]
# ![image.png](attachment:6137bf7b-d734-42c8-8aad-263439d011a6.png)

# %%
import numpy as np
x = np.array([[92,56,88,70,80,49,65,35,66,67]])
y = np.array([[98,68,81,80,83,52,66,30,68,73]])

def grad_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.09

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))


grad_descent(x,y)
# Out:
# m [1622.88  685.44 1283.04 1008.   1195.2   458.64  772.2   189.    807.84
#   880.38], b [17.64 12.24 14.58 14.4  14.94  9.36 11.88  5.4  12.24 13.14], cost [9604. 4624. 6561. 6400. 6889. 2704. 4356.  900. 4624. 5329.] iteration 0
# m [-2469536.496   -385669.6704 -1786119.984   -887221.44   -1374695.136
#   -197380.3104  -585852.696    -41330.52    -631940.9184  -709762.356 ], b [-26842.788   -6886.9584 -20296.818  -12674.592  -17183.6892  -4028.1696
#   -9013.1184  -1180.872   -9574.8624 -10593.468 ], cost [2.22679812e+10 1.46910304e+09 1.27331138e+10 4.96946043e+09
#  9.12940884e+09 5.03137200e+08 2.51390729e+09 4.34333722e+07
#  2.83680656e+09 3.47222634e+09] iteration 1
# m [3.76036485e+09 2.17387252e+08 2.48824503e+09 7.81802796e+08
#  1.58252274e+09 8.51424293e+07 4.45061348e+08 9.07967763e+06
#  4.94974852e+08 5.72921054e+08], b [40873530.9276      3881915.211744   28275511.73579999 11168611.37856
#  19781534.273256    1737600.598656    6847097.666112     259419.36096
# ...

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.09

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 5.58, b 1.6199999999999999, cost 89.0 iteration 0
# m -0.7632000000000003, b -0.06480000000000019, cost 113.24240000000003 iteration 1
# m 6.362928, b 1.978992, cost 144.19294784000004 iteration 2
# m -1.7243251200000014, b -0.19320768000000021, cost 183.70149905254405 iteration 3
# m 7.374170764800002, b 2.3927052672, cost 234.12841033770985 iteration 4
# m -2.9387481937920032, b -0.4000338938880015, cost 298.48539880224337 iteration 5
# m 8.675991532615683, b 2.8788962316595206, cost 380.6152689317344 iteration 6
# m -4.477075667059509, b -0.7043405176516617, cost 485.42123210977206 iteration 7
# m 10.347878033250216, b 3.460061635737772, cost 619.1595028119792 iteration 8
# m -6.4293537558836125, b -1.1306035966501446, cost 789.8126314844135 iteration 9
# m 12.491292622957017, b 4.1647560789240305, cost 1007.5658518817154 iteration 10
# m -8.910435053116855, b -1.7101980316790844, cost 1285.4148677791864 iteration 11
# ...

# %% [markdown]
# # **Home work (How many iteration need to figure the value of m and b)**

# %% [markdown]
# ![image.png](attachment:cdff6703-a8bd-4a82-8562-c65dd990914b.png)

# %% [markdown]
# ![image.png](attachment:93dbb07c-3b4f-4bf1-a590-f02dbae69772.png)

# %%
import numpy as np
x = np.array([[92,56,88,70,80,49,65,35,66,67]])
y = np.array([[98,68,81,80,83,52,66,30,68,73]])
